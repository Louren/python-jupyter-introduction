# %% [markdown]
# # Python for Financial Auditors and Accountants
# Welcome! This notebook will introduce you to the basics of Python programming, which you can use to simplify and enhance your tasks related to accounting and auditing.
#
# ***N.b. this file is generated by GPT-4 and needs review!***

# %% [markdown]
# ## Introduction to Python
# Python is a powerful general-purpose programming language. It is simple and easy to learn. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python's simplicity and readability make it a great language for beginners.

# %% [markdown]
# ## Why Python for Finance?
# Python offers a range of libraries specifically designed for data analysis (like pandas and NumPy), creating visualizations (like matplotlib and Seaborn) and a whole lot more which make it a handy tool for solving problems in the field of finance.

# %% [markdown]
# ## Python Variables
# In Python, variables are storage placeholders for storing different types of data.

# %%
# Here is an example of how to create a variable:
x = 10
y = 'Hello World!'
print(x)
print(y)

# %% [markdown]
# ## Data Types
# Every value in Python has a datatype. Python supports numerous data types like integer, float, string, and complex.

# %%
# Here are examples of different datatypes:
x = 10                # int
y = 10.5              # float
z = 'Hello World!'    # string
print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# ## Basic Arithmetic
# Python performs basic arithmetic operations like any other programming languages namely addition, subtraction, multiplication, and division.

# %%
# Let's do some simple arithmetic:
# addition
sum = 5 + 5
# subtraction
difference = 10 - 5
# multiplication
product = 5 * 5
# division
quotient = 10 / 2

# print the results
print(sum)
print(difference)
print(product)
print(quotient)

# %% [markdown]
# ## Python Libraries for Finance
# We will introduce two primary libraries used in finance:
# - Pandas: for data manipulation and analysis.
# - Matplotlib: for data visualization.

# %% [markdown]
# ## Install Libraries
# The first thing you need to do is to install these libraries. You can do this by using the command "pip install".

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# ## Pandas
# Pandas provides high-performance, easy-to-use data structures and data analysis tools. We'll start by looking at the dataframe and reading data from a CSV file.

# %%
import pandas as pd

# Replace 'file.csv' with your file name.
data = pd.read_csv('fin-data.csv')

# Dsiplay the first 5 rows of the dataframe.
data.head()

# %% [markdown]
# ## Matplotlib
# Matplotlib is a plotting library for the Python programming language. It allows you to create static, animated, and interactive plots in Python.

# %%
import matplotlib.pyplot as plt

# a simple line plot
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('some numbers')
plt.xlabel('some numbers')
plt.show()
